# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")  # чтобы Jupyter видел папку src

from src.data.loader import load_dataset

df = load_dataset("AAPL")
print(df.shape)
print(df.head())
# Out:
# Загружаем данные для AAPL
# [*********************100%***********************]  1 of 1 completed
# (2514, 5)
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-03-03  22.987764  23.035325  22.749959  22.779403  147822800
# 2016-03-04  23.329754  23.497349  22.958326  23.184807  184220400
# 2016-03-07  23.071556  23.288977  22.865458  23.189325  143315600
# 2016-03-08  22.881317  23.046649  22.738635  22.824697  126247600
# 2016-03-09  22.901707  23.005888  22.709197  22.944737  108806800

# %%
from src.data.features import createFeatures

df_features = createFeatures(df)
print(df_features.shape)
print(df_features.tail())
print(df_features["target"].value_counts())
# Out:
# (2504, 10)
# Price            Close        High         Low        Open    Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-02-24  272.140015  274.890015  267.709991  267.859985  47014600
# 2026-02-25  274.230011  274.940002  271.049988  271.779999  33714300
# 2026-02-26  272.950012  276.109985  270.799988  274.950012  32345100
# 2026-02-27  264.179993  272.809998  262.890015  272.809998  72366500
# 2026-03-02  264.720001  266.529999  260.200012  262.410004  41780100
#
# Price         return       SMA_5      SMA_10 volatility_5 target
# Ticker
# Date
# 2026-02-24  0.022391  265.565997  265.839999     4.210281      1
# 2026-02-25  0.007680  267.541998  265.895001     5.589487      0
# 2026-02-26 -0.004668  270.016003  265.640002     4.334252      0
# 2026-02-27 -0.032130  269.936005  265.885001     4.461493      1
# 2026-03-02  0.002044  269.644006  266.779001     4.803448      0
# target
# 1    1339
# 0    1165
# ...
