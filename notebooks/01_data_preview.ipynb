# %%
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
import sys
sys.path.append("..")  # чтобы Jupyter видел папку src

from src.data.loader import load_dataset

df = load_dataset("AAPL")
print(df.shape)
print(df.head())
# Out:
# Загружаем данные для AAPL
# [*********************100%***********************]  1 of 1 completed
# (2515, 5)
# Price           Close       High        Low       Open     Volume
# Ticker           AAPL       AAPL       AAPL       AAPL       AAPL
# Date
# 2016-03-07  23.071566  23.288987  22.865468  23.189335  143315600
# 2016-03-08  22.881317  23.046649  22.738635  22.824697  126247600
# 2016-03-09  22.901703  23.005884  22.709193  22.944733  108806800
# 2016-03-10  22.913029  23.155363  22.682019  22.967385  134054400
# 2016-03-11  23.159895  23.164424  22.987769  23.155364  109632800

# %%
from src.data.features import createFeatures

df_features = createFeatures(df)
print(df_features.shape)
print(df_features.tail())
print(df_features["target"].value_counts())
# Out:
# (2505, 10)
# Price            Close        High         Low        Open    Volume  \
# Ticker            AAPL        AAPL        AAPL        AAPL      AAPL
# Date
# 2026-02-27  264.179993  272.809998  262.890015  272.809998  72366500
# 2026-03-02  264.720001  266.529999  260.200012  262.410004  41827900
# 2026-03-03  263.750000  265.559998  260.130005  263.480011  38568900
# 2026-03-04  262.519989  266.149994  261.420013  264.649994  39803100
# 2026-03-05  260.290009  261.559998  257.250000  260.790009  49658600
#
# Price         return       SMA_5      SMA_10 volatility_5 target
# Ticker
# Date
# 2026-02-27 -0.032130  269.936005  265.885001     4.461493      1
# 2026-03-02  0.002044  269.644006  266.779001     4.803448      0
# 2026-03-03 -0.003664  267.966003  266.766000     5.165347      0
# 2026-03-04 -0.004664  265.623999  266.582999     4.174913      0
# 2026-03-05 -0.008495  263.091998  266.554001     1.763904      0
# target
# 1    1338
# 0    1167
# Name: count, dtype: int64

# %%
from src.data.loader import load_dataset
from src.data.features import createFeatures
from src.models.trainer import train_model

df = load_dataset("AAPL")
df_features = createFeatures(df)
train_model(df_features)
# Out:
# Загружаем данные для AAPL
# [*********************100%***********************]  1 of 1 completed
# Accuracy: 46.51%
#               precision    recall  f1-score   support
#
#         DOWN       0.44      0.81      0.57       223
#           UP       0.55      0.19      0.28       278
#
#     accuracy                           0.47       501
#    macro avg       0.50      0.50      0.43       501
# weighted avg       0.50      0.47      0.41       501
#
# Модель сохранена: models/model.pkl

# %%
from src.models.trainer import train_model

import os
model_path = os.path.join(os.path.dirname(os.getcwd()), "models", "model.pkl")
print(f"Сохраняем в: {model_path}")

train_model(df_features, model_path=model_path)
# Out:
# Сохраняем в: /Users/sanzharsoltybekov/Desktop/ai-trading-telegram-bot/models/model.pkl
#
# Accuracy: 46.51%
#               precision    recall  f1-score   support
#
#         DOWN       0.44      0.81      0.57       223
#           UP       0.55      0.19      0.28       278
#
#     accuracy                           0.47       501
#    macro avg       0.50      0.50      0.43       501
# weighted avg       0.50      0.47      0.41       501
#
# Модель сохранена: /Users/sanzharsoltybekov/Desktop/ai-trading-telegram-bot/models/model.pkl

# %%
from src.models.predictor import make_prediction

result = make_prediction(df_features, model_path=model_path)
print(result)
# Out:
# {'signal': 'DOWN 📉', 'confidence': '54%', 'price': 260.29, 'date': '2026-03-05'}
